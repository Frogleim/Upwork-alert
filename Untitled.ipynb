# %%
import json
import random
import names
import os
import string
import undetected_chromedriver as uc
from selenium.webdriver.common.by import By
import time
from selenium.webdriver.support.ui import Select
from bs4 import BeautifulSoup as BS

# %%
driver = uc.Chrome(version_main=117)

# %%
url = 'https://www.upwork.com/nx/find-work/most-recent'

# %%
driver.get(url)

# %%
email_field = driver.find_element(By.XPATH, '/html/body/div[4]/div/div/div/main/div/div[2]/div[2]/form/div/div/div[1]/div[3]/div/div/div/div/input')
email_field.send_keys('meritelunts1@gmail.com')

# %%
contineu_button = driver.find_element(By.XPATH, "/html/body/div[4]/div/div/div/main/div/div[2]/div[2]/form/div/div/div[1]/button")
contineu_button.click()

# %%
password_field = driver.find_element(By.XPATH, '/html/body/div[4]/div/div/div/main/div/div[2]/div[2]/form/div/div/div[1]/div[3]/div/div/div/input')
password_field.send_keys('077108803Gb')

# %%
login_button = driver.find_element(By.XPATH, "/html/body/div[4]/div/div/div/main/div/div[2]/div[2]/form/div/div/div[1]/button")
login_button.click()

# %%
security_answer = driver.find_element(By.XPATH, "/html/body/div[4]/div/div/div/main/div/div[2]/div[2]/form/div/div/div[1]/div[2]/div[1]/div/div/input")
security_answer.send_keys('mazda')

# %%
login = driver.find_element(By.XPATH, "/html/body/div[4]/div/div/div/main/div/div[2]/div[2]/form/div/div/footer/div/div[1]/div/button")
login.click()

# %% [markdown]
# Scraping data

# %%
soup = BS(driver.page_source, "html.parser")

# %%
jobs_list = soup.find_all('div', {'data-test': 'job-tile-list'})
jobs_list[0]
# Out:
# <div data-test="job-tile-list"><!-- --> <section class="up-card-section up-card-list-section up-card-hover"> <div class="row my-10"><div class="col"><div class="job-tile-badges d-flex mb-10"><!-- --> <!-- --> <span><span><div aria-describedby="popper_1" class="up-badge up-badge-flag up-popper-trigger" data-test="featured-badge" role="button" tabindex="0"><div class="up-icon"><svg aria-hidden="true" role="img" viewbox="0 0 14 14" xmlns="http://www.w3.org/2000/svg"><path d="M3.205 1L0 4.673l6.794 7.608L14 4.683 10.808 1H3.205zm6.028.895h1.136l2.014 2.308h-2.287l-.864-2.308zm-3.505 0h2.536l.863 2.308H4.863l.865-2.308zm-2.105 0H4.76l-.864 2.308H1.608l2.014-2.308zm6.43 3.204h2.18l-4.397 4.976L10.053 5.1zm-5.13 0h4.1l-2.19 4.93-1.91-4.93zm-3.212 0h2.212l1.933 4.98L1.71 5.1z" fill-rule="evenodd"></path></svg></div>
#         Featured
# ...

# %%
for jobs in jobs_list:
    h2_elements = jobs.find('h2')  # Use find_all to find all h2 elements within the div
    description = jobs.find('span', {'data-test': 'job-description-text'})
    job_type = jobs.find('strong', {'data-test': "job-type"})
    posted_on = jobs.find('span', {'data-test': 'posted-on'})
    
    print(description.text.strip())
    print(h2_elements.text.strip())
    print(job_type.text.strip())
    print(posted_on.text.strip())
# Out:
# We have a super clean new stack - Django, Python, HTMX, Tailwind UI with a strong domain model, semantic versioning, GitHub Actions deploying to Digital Ocean App Platform and good test coverage etc. This was a do-over of the earlier platform build, where we learned about the problem and solution space.
#
# See: https://github.com/OpenUnited/platform
#
# I am now seeking a senior Python/Django engineer who can jump in immediately to help us improve customer experience and add some new capabilities. You must be available immediately and you must do the work yourself. If you are thinking about re-selling this contract, it will take me 5 minutes to find out and your account will be deleted. So don't try it.
#
# ...
